# %%
import numpy as np
from astropy import units

import tuesday

rng = np.random.default_rng(1019)
box = rng.uniform(0, 1, size=(10, 10, 10)) * units.mK
ps1d, _ = tuesday.core.calculate_ps_coeval(
    box,
    box_length=200.0 * units.Mpc,
    calc_2d=False,
    calc_1d=True,
)
# Out:
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# File ~/work/21cmfast/tuesday/.venv/lib/python3.12/site-packages/astropy/units/quantity.py:975, in Quantity.to_value(self, unit, equivalencies)
#     974 try:
# --> 975     scale = self.unit._to(unit)
#     976 except Exception:
#     977     # Short-cut failed; try default (maybe equivalencies help).
#
# File ~/work/21cmfast/tuesday/.venv/lib/python3.12/site-packages/astropy/units/core.py:1172, in UnitBase._to(self, other)
#    1170         return self_decomposed.scale / other_decomposed.scale
# -> 1172 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# UnitConversionError: 'Unit("Mpc")' is not a scaled version of 'Unit(dimensionless)'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# ...

# %%
ps1d.k
# Out:
# <Quantity [       nan, 0.05441398, 0.09179854, 0.1350342 ] 1 / Mpc>
